# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
m=np.array([5, 15, 20, 25, 30, 35, 40, 45, 50, 55])
Obs=np.array([3.96863, 2.82549, 3.04489, 3.3085, 2.8849, 4.07995, 7.97069, 2.89264, 3.33693, 3.97197])
exp=np.array([3.06069, 3.03231, 3.1143, 3.0343, 3.2164, 3.2031, 3.3403, 3.52974, 3.5021, 3.6234])

# %%
fig, ax = plt.subplots(figsize=(8,8))
ax.plot(m, Obs, label = r'$M_{Z_{D}} = 88 [GeV]$', color='b')
ax.plot(m, exp, label = r'$M_{Z_{D}} = 95 [GeV]$', color='r')
plt.grid(True, which="both", ls="--")
# ax.grid(self, b=None, which='major', axis='both', **kwargs)
plt.rcParams.update({'font.size': 24})
ax.set_xlabel(r'$m_{s_{D}}$ [GeV]')
ax.set_ylabel(r'95% CL upper limit on n')
# plt.title(r'$CMS\ Preliminary\ 59.97fb^{-1} \ (13 TeV)$') 
plt.title(r'$CMS \ Preliminary$', loc='left')
plt.title(r'$59.97fb^{-1} \ (13 TeV)$', loc='right')
plt.legend(bbox_to_anchor=(1, 1))
# ax.set_facecolor('black')
plt.show()
# fig.savefig('Limits_all_samples_AnLimit_range.pdf')
