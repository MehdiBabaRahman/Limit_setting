# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
N85=np.array([3.06069, 3.03231, 3.1143, 3.0343, 3.2164, 3.2031, 3.3403])
N88=np.array([3.06069, 3.03231, 3.1143, 3.0343, 3.2164, 3.2031, 3.3403])
N95=np.array([3.06069, 3.03231, 3.1143, 3.0343, 3.2164, 3.2031, 3.3403, 3.52974])
N100=np.array([3.06069, 3.03231, 3.1143, 3.0343, 3.2164, 3.2031, 3.3403, 3.52974, 3.5021])
N=np.array([3.06069, 3.03231, 3.1143, 3.0343, 3.2164, 3.2031, 3.3403, 3.52974, 3.5021, 3.6234])
r=0.418
L=59.7

# %%
msD85=([5, 15, 20, 25, 30, 35, 40])
alpha85=np.array([0.0527, 0.0371, 0.038, 0.0313, 0.0415, 0.0557, 0.0448])
alpha85err=np.array([0.00223, 0.00189, 0.00191, 0.00174, 0.00199, 0.00229, 0.00207])
Br85=np.array([0.991335, 0.9896576, 0.9876927, 0.9840724, 0.9764805, 0.9552091, 0.8184361])

msD88=([5, 15, 20, 25, 30, 35, 40])
alpha88=np.array([0.0622, 0.0568, 0.0454, 0.04, 0.047, 0.0721, 0.0707])
alpha88err=np.array([0.00242, 0.00231, 0.00208, 0.00196, 0.00212, 0.00259, 0.00256])

msD91=([5, 15, 20, 25, 30, 35, 40, 45])
alpha91=np.array([0.085, 0.0709, 0.0612, 0.056, 0.0527, 0.0852, 0.0983, 0.0576])
alpha91err=np.array([0.00279, 0.00257, 0.0024, 0.0023, 0.00223, 0.00279, 0.00298, 0.00233])
Br91=np.array([5.43E-02, 4.69E-02, 4.07E-02, 3.31E-02, 2.44E-02, 1.52E-02, 0.006424469, 2.43E-04])

msD95=([5, 15, 20, 25, 30, 35, 40, 45])
alpha95=np.array([0.102, 0.0883, 0.0772, 0.0776, 0.0785, 0.1, 0.122, 0.105])
alpha95err=np.array([0.00302, 0.00284, 0.00267, 0.00268, 0.00269, 0.003, 0.00327, 0.00307])
Br95=np.array([0.834501, 0.8141195, 0.7927962, 0.7591538, 0.7049769, 0.6130577, 0.4457657, 0.1440122])


msD100=([5, 15, 20, 25, 30, 35, 40, 45, 50])
alpha100=np.array([0.127, 0.12, 0.11 , 0.102, 0.0995, 0.114, 0.14, 0.152, 0.14])
alpha100err=np.array([0.00333, 0.00325, 0.00313, 0.00302, 0.00299, 0.00318, 0.00347, 0.00359, 0.00366])
Br100=np.array([0.9379248, 0.9301459, 0.9219303, 0.9087838, 0.8870511, 0.8481779, 0.7681548, 0.5595414, 5.41E-03])

msD110=([5, 15, 20, 25, 30, 35, 40, 45, 50, 55])
alpha110=np.array([0.159, 0.16, 0.153, 0.149, 0.143, 0.155, 0.18, 0.208, 0.214, 0.258])
alpha110err=np.array([0.00366, 0.00367, 0.0036, 0.00356, 0.0035, 0.00362, 0.00384, 0.00406, 0.0041, 0.00438])
Br110=np.array([0.9683876, 0.9650612, 0.961646, 0.9563687, 0.9480843, 0.9343703, 0.9093251, 0.8549749, 0.6916041, 0.1615622])


msD125=np.array([5, 15, 20, 25, 30, 35, 40, 45, 50, 55])
# , 60
alpha125=np.array([0.206, 0.204, 0.192, 0.189, 0.191, 0.191, 0.218, 0.248, 0.266, 0.27])
# , 0.294
alpha125err=np.array([0.00404, 0.00403, 0.00394, 0.00391, 0.00393, 0.00393, 0.00413, 0.00432, 0.00442, 0.00444])
# , 0.00456
Br125=np.array([0.9777279, 0.9759327, 0.9741557, 0.9715293, 0.9676639, 0.9618408, 0.9526236, 0.9367645, 0.9054284, 0.8260719])
# , 0.4931581


msD130=np.array([5, 15, 20, 25, 30, 35, 40, 45, 50, 55])
#                  , 60, 65])
alpha130=np.array([0.23, 0.219, 0.211, 0.199, 0.2, 0.213, 0.231, 0.257, 0.273, 0.281])
#                 , 0.292,   0.34])
alpha130err=np.array([0.00421, 0.00408, 0.00399, 0.004, 0.004, 0.00409, 0.00422, 0.00437, 0.00446, 0.00449])
#                     , 0.00455, 0.00474])
Br130=np.array([0.9790809, 0.9775282, 0.976006, 0.9737816, 0.9705603, 0.965817, 0.9585505, 0.9466478, 0.924921, 0.8772679])
#                , 0.7287561 , 0.1651773])


msD140=np.array([5, 15, 20, 25, 30, 35, 40, 45, 50, 55])
#                 , 60 , 65, 70])
alpha140=np.array([0.242, 0.233, 0.236, 0.234, 0.236, 0.23, 0.247, 0.273, 0.295, 0.303])
#                  , 0.306  , 0.32, 0.352])
alpha140err=np.array([0.00428, 0.00422, 0.00425, 0.00423, 0.00425, 0.00421, 0.00431, 0.00446, 0.00456, 0.0046])
#                     , 0.00461  , 0.00466, 0.00478])
Br140=np.array([0.980875, 0.9796599, 0.9784877, 0.9768071, 0.9744369, 0.9710722, 0.9661752, 0.9587249, 0.9465698, 0.9244343])
#                ,0.87597050  , 0.7254587, 0.1592373])


msD150=np.array([5, 15, 20, 25, 30, 35, 40, 45, 50, 55])
#               , 60   , 70, 75]) 
alpha150=np.array([0.279, 0.256, 0.255, 0.253, 0.254, 0.259, 0.261, 0.284, 0.314, 0.319])
#                    , 0.327, 0.35, 0.38]) 
alpha150err=np.array([0.00449, 0.00437, 0.00436, 0.00435, 0.00435, 0.00438, 0.00439, 0.00451, 0.00464, 0.00466])
#                    , 0.00469   , 0.00477, 0.00485])
Br150=np.array([0.9820027, 0.9810128, 0.9800702, 0.9787388, 0.9768994, 0.9743601, 0.9742, 0.9656641, 0.9578871, 0.9452407])
#               , 0.003357175  , 0.00071919, 4.67E-05])


msD160=np.array([5, 15, 20, 25, 30, 35, 40, 45, 50, 55])
#                 , 60 , 70, 80]) 
alpha160=np.array([0.289, 0.286, 0.276, 0.274, 0.262, 0.28, 0.282, 0.294, 0.318, 0.333])
#                   , 0.342 , 0.358, 0.394]) 
alpha160err=np.array([0.00453, 0.00452, 0.00447, 0.00446, 0.0044, 0.00449, 0.0045, 0.00456, 0.00466, 0.00497])
#                     , 0.00474  , 0.00479, 0.00489])
Br160=np.array([0.9827719, 0.9819435, 0.9811627, 0.9800734, 0.9785927, 0.9765927, 0.9738698, 0.9700878, 0.9646589, 0.9564723])
#                , 0.9431973 , 0.8668581, 0.1585744])

msD170=np.array([5, 15, 20, 25, 30, 35, 40, 45, 50, 55])
alpha170=np.array([0.309, 0.306, 0.292, 0.3, 0.294, 0.283, 0.285, 0.302, 0.318, 0.345])
alpha170err=np.array([0.00462, 0.00461, 0.00455, 0.00458, 0.00456, 0.00451, 0.00452, 0.00459, 0.00466, 0.00475])
Br170=np.array([0.9833269, 0.9826198, 0.9819592, 0.9810465, 0.9798222, 0.978197, 0.9760339, 0.9731171, 0.9690915, 0.9633376])


msD180=np.array([5, 15, 20, 25, 30, 35, 40, 45, 50, 55])
#                  , 60, 70, 80, 90]) 
alpha180=np.array([0.329, 0.315, 0.317, 0.3, 0.308, 0.3, 0.317, 0.323, 0.343, 0.363])
#                   , 0.364 , 0.375, 0.4, 0.407]) 
alpha180err=np.array([0.0047, 0.00465, 0.00465, 0.00458, 0.00461, 0.00458, 0.00465, 0.00468, 0.00475, 0.00481])
#                      , 0.00481 , 0.00484, 0.0049, 0.00491])
Br180=np.array([0.9837441, 0.9831315, 0.9825632, 0.9817845, 0.9807513, 0.9793988, 0.977631, 0.975302, 0.9721832, 0.9678991])
#                , 0.9617962 , 0.9378756, 0.8539215, 0.158393])

msD180=np.array([5, 15, 20, 25, 30, 35, 40, 45, 50, 55])
#                , 60  , 70, 80, 90]) 
alpha180=np.array([0.329, 0.315, 0.317, 0.3, 0.308, 0.3, 0.317, 0.323, 0.343, 0.363,])
#                    0.364 , 0.375, 0.4, 0.407]) 
alpha180err=np.array([0.0047, 0.00465, 0.00465, 0.00458, 0.00461, 0.00458, 0.00465, 0.00468, 0.00475, 0.00481])
#                      , 0.00481 , 0.00484, 0.0049, 0.00491])
Br180=np.array([0.9837441, 0.9831315, 0.9825632, 0.9817845, 0.9807513, 0.9793988, 0.977631, 0.975302, 0.9721832, 0.9678991])
#                , 0.9617962 , 0.9378756, 0.8539215, 0.158393])


msD190=np.array([5, 15, 20, 25, 30, 35, 40, 45, 50, 55])
#                 , 60 , 70, 80]) 
alpha190=np.array([0.341, 0.332, 0.343, 0.322, 0.327, 0.327, 0.327, 0.329, 0.345, 0.368])
#                   , 0.383 , 0.383, 0.387]) 
alpha190err=np.array([0.00474, 0.00471, 0.00475, 0.00467, 0.00469, 0.00469, 0.00469, 0.0047, 0.00475, 0.00482])
#                       , 0.00486, 0.00486, 0.00487])
Br190=np.array([0.9840678, 0.9835305, 0.9830353, 0.9823613, 0.9814749, 0.9803282, 0.9788511, 0.9769412, 0.9744435, 0.9711158])
#               , 0.9665616  , 0.9504104, 0.9067967])



msD200=np.array([5, 15, 20, 25, 30, 35, 40, 45, 50, 55])
#                 , 60 , 80, 100]) 
alpha200=np.array([0.354, 0.345, 0.358, 0.347, 0.341, 0.331, 0.337, 0.342, 0.352, 0.368])
#                   , 0.373 , 0.407, 0.428]) 
alpha200err=np.array([0.00478, 0.00475, 0.00479, 0.00476, 0.00474, 0.00471, 0.00473, 0.00475, 0.00478, 0.00482])
#                       , 0.00484 , 0.00491, 0.00495]) 
Br200=np.array([0.984, 0.9838494, 0.983, 0.9828227, 0.982, 0.9810651, 0.979, 0.9782093, 0.976, 0.9734875])
#                , 0.969 , 0.931, 0.157])

# %%
sigBr85=N85/(L*r*alpha85)
sigBr85err=(N85/(L*r))*(alpha85err/(alpha85*alpha85))
print ('MZD85: ', sigBr85, '\n')

sigBr88=N88/(L*r*alpha88)
sigBr88err=(N88/(L*r))*(alpha88err/(alpha88*alpha85))
print ('MZD88: ', sigBr88, '\n')


# sigBr91=N91/(L*r*alpha91)
# sigBr91err=(N/(L*r))*(alpha91err/(alpha91*alpha91))

sigBr95=N95/(L*r*alpha95)
sigBr95err=(N95/(L*r))*(alpha95err/(alpha95*alpha95))
print ('MZD95: ', sigBr95, '\n')


sigBr100=N100/(L*r*alpha100)
sigBr100err=(N100/(L*r))*(alpha100err/(alpha100*alpha100))
print ('MZD100: ', sigBr100, '\n')

sigBr110=N/(L*r*alpha110)
sigBr110err=(N/(L*r))*(alpha110err/(alpha110*alpha110))
print ('MZD110: ', sigBr110, '\n')


sigBr125=N/(L*r*alpha125)
sigBr125err=(N/(L*r))*(alpha125err/(alpha125*alpha125))
print ('MZD125: ', sigBr125, '\n')


sigBr130=N/(L*r*alpha130)
sigBr130err=(N/(L*r))*(alpha130err/(alpha130*alpha130))
print ('MZD130: ', sigBr130, '\n')


sigBr140=N/(L*r*alpha140)
sigBr140err=(N/(L*r))*(alpha140err/(alpha140*alpha140))
print ('MZD140: ', sigBr140, '\n')


sigBr150=N/(L*r*alpha150)
sigBr150err=(N/(L*r))*(alpha150err/(alpha150*alpha150))
print ('MZD150: ', sigBr150, '\n')


sigBr160=N/(L*r*alpha160)
sigBr160err=(N/(L*r))*(alpha160err/(alpha160*alpha160))
print ('MZD160: ', sigBr160, '\n')


sigBr170=N/(L*r*alpha170)
sigBr170err=(N/(L*r))*(alpha170err/(alpha170*alpha170))
print ('MZD170: ', sigBr170, '\n')


sigBr180=N/(L*r*alpha180)
sigBr180err=(N/(L*r))*(alpha180err/(alpha180*alpha180))
print ('MZD180: ', sigBr180, '\n')


sigBr190=N/(L*r*alpha190)
sigBr190err=(N/(L*r))*(alpha190err/(alpha190*alpha190))
print ('MZD190: ', sigBr190, '\n')


sigBr200=N/(L*r*alpha200)
sigBr200err=(N/(L*r))*(alpha200err/(alpha200*alpha200))
print ('MZD200: ', sigBr200, '\n')
# Out:
# MZD85:  [2.3273308  3.27528484 3.28417459 3.88475439 3.10578468 2.3044362
#  2.98783663]
#
# [1.97187031 2.13931457 2.7488686  3.03982031 2.74234179 1.78026486
#  1.89328261]
# MZD88:  [1.97187031 2.13931457 2.7488686  3.03982031 2.74234179 1.78026486
#  1.89328261]
#
# MZD95:  [1.20245425 1.37613893 1.61656262 1.56691769 1.64191165 1.28357096
#  1.09717279 1.34710921]
#
# MZD100:  [0.96575065 1.0126089  1.13453304 1.1920864  1.29537753 1.12593944
#  0.95610772 0.93056886 1.0024204 ]
#
# MZD110:  [0.77138574 0.75945667 0.81567735 0.81605914 0.90132912 0.8281103
#  0.74363934 0.68003109 0.65578904 0.56278947]
#
# MZD125:  [0.59538997 0.59565229 0.64999289 0.64334821 0.67481709 0.67202668
#  0.61401413 0.57034866 0.52758968 0.5377766 ]
#
# MZD130:  [0.53326232 0.55485419 0.59146272 0.61101916 0.64445032 0.60261548
#  0.57945922 0.55037536 0.51406174 0.51672485]
#
# MZD140:  [0.50681956 0.52151531 0.52880777 0.5196274  0.54614434 0.55807433
# ...

# %%
##Ploting limits 
fig, ax = plt.subplots(figsize=(8,8))
colors=[]
for i in range (14):
    color = plt.cm.rainbow(np.linspace(1,0,14)[i])
    colors.append(color)
ax.errorbar(msD85, sigBr85, sigBr85err, label = r'$M_{Z_{D}} = 85 [GeV]$', c=colors[0])
ax.errorbar(msD88, sigBr88, sigBr88err, label = r'$M_{Z_{D}} = 88 [GeV]$', c=colors[1])
ax.errorbar(msD95, sigBr95, sigBr95err, label = r'$M_{Z_{D}} = 95 [GeV]$', c=colors[2])
ax.errorbar(msD100, sigBr100, sigBr100err, label = r'$M_{Z_{D}} = 100 [GeV]$', c=colors[3])
ax.errorbar(msD110, sigBr110, sigBr110err, label = r'$M_{Z_{D}} = 110 [GeV]$', c=colors[4])
ax.errorbar(msD125, sigBr125, sigBr125err, label = r'$M_{Z_{D}} = 125 [GeV]$', c=colors[5])
ax.errorbar(msD130, sigBr130, sigBr130err, label = r'$M_{Z_{D}} = 130 [GeV]$', c=colors[6])
ax.errorbar(msD140, sigBr140, sigBr140err, label = r'$M_{Z_{D}} = 140 [GeV]$', c=colors[7])
ax.errorbar(msD150, sigBr150, sigBr150err, label = r'$M_{Z_{D}} = 150 [GeV]$', c=colors[8])
ax.errorbar(msD160, sigBr160, sigBr160err, label = r'$M_{Z_{D}} = 160 [GeV]$', c=colors[9])
ax.errorbar(msD170, sigBr170, sigBr170err, label = r'$M_{Z_{D}} = 170 [GeV]$', c=colors[10])
ax.errorbar(msD180, sigBr180, sigBr180err, label = r'$M_{Z_{D}} = 180 [GeV]$', c=colors[11])
ax.errorbar(msD190, sigBr190, sigBr190err, label = r'$M_{Z_{D}} = 190 [GeV]$', c=colors[12])
ax.errorbar(msD200, sigBr200, sigBr200err, label = r'$M_{Z_{D}} = 200 [GeV]$', c=colors[13])
# plt.yscale('symlog')
# plt.xscale('symlog')
# plt.loglog(x, y)
ax.loglog()
ax.set_ylim([0,10])
ax.set_xlim([4,200])


plt.grid(True, which="both", ls="--")
# ax.grid(self, b=None, which='major', axis='both', **kwargs)
plt.rcParams.update({'font.size': 12})
ax.set_xlabel(r'$M_{s_{D}}$ [GeV]')
ax.set_ylabel(r'95% CL upper limit on $\sigma(pp \rightarrow Z_{D}) \times \mathcal{B}(Z_{D} \rightarrow s_{D} \bar{s_{D})} \times \mathcal{B}^{2} (s_{D} \rightarrow 2\mu) $ [fb]')
# plt.title(r'$CMS\ Preliminary\ 59.97fb^{-1} \ (13 TeV)$') 
plt.title(r'$CMS \ Preliminary$', loc='left')
plt.title(r'$59.97fb^{-1} \ (13 TeV)$', loc='right')
plt.legend(bbox_to_anchor=(1, 1))
# ax.set_facecolor('black')
plt.show()
fig.savefig('Limits_all_samples_AnLimit_range.pdf')
# Out:
# <ipython-input-5-acf25545c412>:25: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax.set_ylim([0,10])
# Substituting symbol B from STIXNonUnicode
# Substituting symbol B from STIXNonUnicode
# Substituting symbol B from STIXNonUnicode

# %%
##ploting BR and alpha separatly 
fig, ax = plt.subplots(figsize=(10,10))

colors=[]
for i in range (12):
    color = plt.cm.rainbow(np.linspace(1,0,12)[i])
    colors.append(color)

ax.errorbar(msD85, alpha85, alpha85err , label = r'$M_{Z_{D}} = 85 [GeV], \alpha_{gen}$', c=colors[0])
ax.plot(msD85, Br85, '--' ,label = r'$M_{Z_{D}} = 85 [GeV], BR$', c=colors[0])

ax.errorbar(msD91, alpha91, alpha91err , label = r'$M_{Z_{D}} = 91.18 [GeV], \alpha_{gen}$', c=colors[1])
ax.plot(msD91, Br91, '--' ,label = r'$M_{Z_{D}} = 91.18 [GeV], BR$', c=colors[1])

ax.errorbar(msD95, alpha95, alpha95err , label = r'$M_{Z_{D}} = 95 [GeV], \alpha_{gen}$', c=colors[2])
ax.plot(msD95, Br95, '--' ,label = r'$M_{Z_{D}} = 95 [GeV], BR$', c=colors[2])

ax.errorbar(msD100, alpha100, alpha100err , label = r'$M_{Z_{D}} = 100 [GeV], \alpha_{gen}$', c=colors[3])
ax.plot(msD100, Br100, '--' ,label = r'$M_{Z_{D}} = 100 [GeV], BR$', c=colors[3])

ax.errorbar(msD125, alpha125, alpha125err ,label = r'$M_{Z_{D}} = 125 [GeV], \alpha_{gen}$', c=colors[4])
ax.plot(msD125, Br125, '--' ,label = r'$M_{Z_{D}} = 125 [GeV], BR$', c=colors[4])

ax.errorbar(msD130, alpha130, alpha130err ,label = r'$M_{Z_{D}} = 130 [GeV], \alpha_{gen}$', c=colors[5])
ax.plot(msD125, Br130, '--' ,label = r'$M_{Z_{D}} = 130 [GeV], BR$', c=colors[5])

ax.errorbar(msD140, alpha140, alpha140err , label = r'$M_{Z_{D}} = 140 [GeV], \alpha_{gen}$', c=colors[6])
ax.plot(msD140, Br140, '--' ,label = r'$M_{Z_{D}} = 140 [GeV], BR$', c=colors[6])

ax.errorbar(msD150, alpha150, alpha150err , label = r'$M_{Z_{D}} = 150 [GeV], \alpha_{gen}$', c=colors[7])
ax.plot(msD150, Br150, '--' ,label = r'$M_{Z_{D}} = 150 [GeV], BR$', c=colors[7])

ax.errorbar(msD160, alpha160, alpha160err , label = r'$M_{Z_{D}} = 160 [GeV], \alpha_{gen}$', c=colors[8])
ax.plot(msD160, Br160, '--' ,label = r'$M_{Z_{D}} = 160 [GeV], BR$', c=colors[8])

ax.errorbar(msD180, alpha180, alpha180err , label = r'$M_{Z_{D}} = 180 [GeV], \alpha_{gen}$', c=colors[9])
ax.plot(msD180, Br180, '--' ,label = r'$M_{Z_{D}} = 180 [GeV], BR$', c=colors[9])

ax.errorbar(msD190, alpha190, alpha190err , label = r'$M_{Z_{D}} = 190 [GeV], \alpha_{gen}$', c=colors[10])
ax.plot(msD190, Br190, '--' ,label = r'$M_{Z_{D}} = 190 [GeV], BR$', c=colors[10])

ax.errorbar(msD200, alpha200, alpha200err ,label = r'$M_{Z_{D}} = 200 [GeV], \alpha_{gen}$', c=colors[11])
ax.plot(msD200, Br200, '--' ,label = r'$M_{Z_{D}} = 200 [GeV], BR$', c=colors[11])

# ax.set_xlim([0,90])
# ax.set_ylim([0,1.2])
ax.loglog()
ax.set_ylim([0.01,2])
ax.set_xlim([4,200])

ax.set_xlabel(r'$M_{s_{D}}$ [GeV]')
ax.set_ylabel('Variable')
plt.grid()
# plt.legend(loc='upper left', prop={'size': 1})
plt.legend(bbox_to_anchor=(1.35, 1.05))
plt.title(r'$\alpha_{gen} \ and \ BR \ Curves$') 
ax.set_facecolor('black')
fig.tight_layout()
fig.savefig('Br_alpha.pdf')
plt.show()

# %%
##efficiencies for Zd=91.1876 masses
msD=np.array([1,2,3,4,5])
##MSD=5 GeV
#cuts

msD5_91_cuts_releff=np.array([0.521, 0.517, 0.785, 0.402, 1])
msD5_91_cuts_totaleff=np.array([0.521, 0.269 , 0.211, 0.085, 0.085 ])


##MSD=15 GeV
#cuts
msD15_91_cuts_releff=np.array([0.512, 0.492, 0.78, 0.361, 1])
msD15_91_cuts_totaleff=np.array([0.512,  0.252,  0.196, 0.0709, 0.0709])


##MSD=20 GeV
#cuts
msD20_91_cuts_releff=np.array([0.509, 0.463, 0.746, 0.348,1])
msD20_91_cuts_totaleff=np.array([0.509, 0.236, 0.176, 0.0612, 0.0612])


##MSD=25 GeV
#cuts
msD25_91_cuts_releff=np.array([0.508, 0.448, 0.748, 0.329, 1])
msD25_91_cuts_totaleff=np.array([0.508,0.228, 0.17, 0.056, 0.056])


##MSD=30 GeV
#cuts
msD30_91_cuts_releff=np.array([0.477, 0.421, 0.769, 0.342, 1])
msD30_91_cuts_totaleff=np.array([0.477, 0.201, 0.154, 0.0527, 0.0527])


##MSD=35 GeV
#cuts
msD35_91_cuts_releff=np.array([0.46, 0.378, 0.9, 0.544, 1])
msD35_91_cuts_totaleff=np.array([0.46, 0.174, 0.157, 0.0852, 0.0852])


##MSD=40 GeV
#cuts
msD40_91_cuts_releff=np.array([0.433, 0.323, 0.965, 0.728, 1])
msD40_91_cuts_totaleff=np.array([0.433, 0.14, 0.135, 0.0983, 0.0983])


##MSD=45 GeV
#cuts
msD45_91_cuts_releff=np.array([0.291, 0.249, 0.967, 0.824, 1])
msD45_91_cuts_totaleff=np.array([0.291, 0.0723, 0.0699, 0.0576, 0.0576])

# %%
fig, ax = plt.subplots(figsize=(10,10))
colors=[]
for i in range (8):
    color = plt.cm.rainbow(np.linspace(1,0,8)[i])
    colors.append(color)
    
ax.plot(msD, msD5_91_cuts_totaleff, '--' ,label = r'$ms_{D}=5$ GeV', c=colors[0])
ax.plot(msD, msD15_91_cuts_totaleff, '--' ,label = r'$ms_{D}=15$ GeV', c=colors[1])
ax.plot(msD, msD20_91_cuts_totaleff, '--' ,label = r'$ms_{D}=20$ GeV', c=colors[2])
ax.plot(msD, msD25_91_cuts_totaleff, '--' ,label = r'$ms_{D}=25$ GeV', c=colors[3])
ax.plot(msD, msD30_91_cuts_totaleff, '--' ,label = r'$ms_{D}=30$ GeV', c=colors[4])
ax.plot(msD, msD35_91_cuts_totaleff, '--' ,label = r'$ms_{D}=35$ GeV', c=colors[5])
ax.plot(msD, msD40_91_cuts_totaleff, '--' ,label = r'$ms_{D}=40$ GeV', c=colors[6])
ax.plot(msD, msD45_91_cuts_totaleff, '--' ,label = r'$ms_{D}=45$ GeV', c=colors[7])
my_xticks = ['1GenMu24Eta2','2GenMu24Eta2','3GenMu8','4GenMu8', 'Decay in Phase 1 pixdet']
plt.xticks(msD, my_xticks)
plt.grid()
ax.set_facecolor('black')
plt.legend()
ax.set_ylim([0,1])
plt.title(r'$MZ_{D}=91.18 \ GeV \ Total \ Eff.$') 
fig.savefig('MZD_91_tot_eff.pdf')

# %%
fig, ax = plt.subplots(figsize=(10,10))
colors=[]
for i in range (8):
    color = plt.cm.rainbow(np.linspace(1,0,8)[i])
    colors.append(color)
ax.plot(msD, msD5_91_cuts_releff, '--' ,label = r'$ms_{D}=5$ GeV', c=colors[0])
ax.plot(msD, msD15_91_cuts_releff, '--' ,label = r'$ms_{D}=15$ GeV', c=colors[1])
ax.plot(msD, msD20_91_cuts_releff, '--' ,label = r'$ms_{D}=20$ GeV', c=colors[2])
ax.plot(msD, msD25_91_cuts_releff, '--' ,label = r'$ms_{D}=25$ GeV', c=colors[3])
ax.plot(msD, msD30_91_cuts_releff, '--' ,label = r'$ms_{D}=30$ GeV', c=colors[4])
ax.plot(msD, msD35_91_cuts_releff, '--' ,label = r'$ms_{D}=35$ GeV', c=colors[5])
ax.plot(msD, msD40_91_cuts_releff, '--' ,label = r'$ms_{D}=40$ GeV', c=colors[6])
ax.plot(msD, msD45_91_cuts_releff, '--' ,label = r'$ms_{D}=45$ GeV', c=colors[7])
my_xticks = ['1GenMu24Eta2','2GenMu24Eta2','3GenMu8','4GenMu8', 'Decay in Phase 1 pixdet']
plt.xticks(msD, my_xticks)
ax.set_facecolor('black')
ax.set_ylim([0,1])
plt.grid()
plt.legend()
plt.title(r'$MZ_{D}=91.18 \ GeV \ Rel. \ Eff.$') 
fig.savefig('MZD_91_rel_eff.pdf')

# %%
##efficiencies for Zd=125 masses
msD=np.array([1,2,3,4,5])
##MSD=5 GeV
#cuts

msD5_125_cuts_releff=np.array([0.636, 0.666, 0.887, 0.547, 1])
msD5_125_cuts_totaleff=np.array([0.636, 0.423, 0.376, 0.206, 0.206])


##MSD=15 GeV
#cuts
msD15_125_cuts_releff=np.array([0.636, 0.654, 0.903, 0.543, 1])
msD15_125_cuts_totaleff=np.array([0.636, 0.416, 0.375, 0.204, 0.204 ])


##MSD=20 GeV
#cuts
msD20_125_cuts_releff=np.array([0.642, 0.655, 0.893, 0.511, 1])
msD20_125_cuts_totaleff=np.array([0.642, 0.421, 0.376, 0.192, 0.192])


##MSD=25 GeV
#cuts
msD25_125_cuts_releff=np.array([0.642, 0.658, 0.892, 0.5, 1])
msD25_125_cuts_totaleff=np.array([0.642, 0.422, 0.377, 0.189, 0.189])


##MSD=30 GeV
#cuts
msD30_125_cuts_releff=np.array([0.64, 0.671, 0.884, 0.504, 1])
msD30_125_cuts_totaleff=np.array([0.64, 0.429, 0.38, 0.191, 0.191])


##MSD=35 GeV
#cuts
msD35_125_cuts_releff=np.array([0.63, 0.66, 0.893, 0.515, 1])
msD35_125_cuts_totaleff=np.array([0.63, 0.416, 0.371, 0.191, 0.191])


##MSD=40 GeV
#cuts
msD40_125_cuts_releff=np.array([0.633, 0.665, 0.913, 0.567, 1])
msD40_125_cuts_totaleff=np.array([0.633, 0.421, 0.385, 0.218, 0.218])


##MSD=45 GeV
#cuts
msD45_125_cuts_releff=np.array([0.63, 0.65, 0.947, 0.64, 1])
msD45_125_cuts_totaleff=np.array([0.63, 0.41, 0.388, 0.248, 0.248])

##MSD=50 GeV
#cuts
msD50_125_cuts_releff=np.array([0.625, 0.649, 0.948, 0.692, 1])
msD50_125_cuts_totaleff=np.array([0.625, 0.405, 0.385, 0.266, 0.266])

##MSD=55 GeV
#cuts
msD55_125_cuts_releff=np.array([0.616, 0.632, 0.949, 0.731, 1])
msD55_125_cuts_totaleff=np.array([0.616, 0.39, 0.37, 0.27, 0.27])

##MSD=60 GeV
#cuts
msD60_125_cuts_releff=np.array([0.604, 0.649, 0.952, 0.79, 1])
msD60_125_cuts_totaleff=np.array([0.604, 0.392, 0.373, 0.294, 0.294])

# %%
fig, ax = plt.subplots(figsize=(10,10))
colors=[]
for i in range (13):
    color = plt.cm.rainbow(np.linspace(1,0,13)[i])
    colors.append(color)
ax.plot(msD, msD5_125_cuts_totaleff, '--' ,label = r'$ms_{D}=5$ GeV', c=colors[0])
ax.plot(msD, msD15_125_cuts_totaleff, '--' ,label = r'$ms_{D}=15$ GeV', c=colors[1])
ax.plot(msD, msD20_125_cuts_totaleff, '--' ,label = r'$ms_{D}=20$ GeV', c=colors[3])
ax.plot(msD, msD25_125_cuts_totaleff, '--' ,label = r'$ms_{D}=25$ GeV', c=colors[4])
ax.plot(msD, msD30_125_cuts_totaleff, '--' ,label = r'$ms_{D}=30$ GeV', c=colors[5])
ax.plot(msD, msD35_125_cuts_totaleff, '--' ,label = r'$ms_{D}=35$ GeV', c=colors[6])
ax.plot(msD, msD40_125_cuts_totaleff, '--' ,label = r'$ms_{D}=40$ GeV', c=colors[7])
ax.plot(msD, msD45_125_cuts_totaleff, '--' ,label = r'$ms_{D}=45$ GeV', c=colors[8])
ax.plot(msD, msD50_125_cuts_totaleff, '--' ,label = r'$ms_{D}=50$ GeV', c=colors[9])
ax.plot(msD, msD55_125_cuts_totaleff, '--' ,label = r'$ms_{D}=55$ GeV', c=colors[10])
ax.plot(msD, msD60_125_cuts_totaleff, '--' ,label = r'$ms_{D}=60$ GeV', c=colors[12])

my_xticks = ['1GenMu24Eta2','2GenMu24Eta2','3GenMu8','4GenMu8', 'Decay in Phase 1 pixdet']
plt.xticks(msD, my_xticks)
plt.legend()
ax.set_ylim([0,1])
plt.grid()
plt.title(r'$MZ_{D}=125 \ GeV \ Total \ Eff.$') 
ax.set_facecolor('black')
fig.savefig('MZD_125_tot_eff.pdf')

# %%
fig, ax = plt.subplots(figsize=(10,10))
colors=[]
for i in range (11):
    color = plt.cm.rainbow(np.linspace(1,0,11)[i])
    colors.append(color)
'''
ax.plot(msD, msD5_125_cuts_releff, '--' ,label = r'$ms_{D}=5$ GeV', c='cyan')
ax.plot(msD, msD15_125_cuts_releff, '--' ,label = r'$ms_{D}=15$ GeV', c='deepskyblue')
ax.plot(msD, msD20_125_cuts_releff, '--' ,label = r'$ms_{D}=20$ GeV', c='dodgerblue')
ax.plot(msD, msD25_125_cuts_releff, '--' ,label = r'$ms_{D}=25$ GeV', c='darkcyan')
ax.plot(msD, msD30_125_cuts_releff, '--' ,label = r'$ms_{D}=30$ GeV', c='green')
ax.plot(msD, msD35_125_cuts_releff, '--' ,label = r'$ms_{D}=35$ GeV', c='lime')
ax.plot(msD, msD40_125_cuts_releff, '--' ,label = r'$ms_{D}=40$ GeV', c='yellow')
ax.plot(msD, msD45_125_cuts_releff, '--' ,label = r'$ms_{D}=45$ GeV', c='orange')
ax.plot(msD, msD50_125_cuts_releff, '--' ,label = r'$ms_{D}=50$ GeV', c='orangered')
ax.plot(msD, msD55_125_cuts_releff, '--' ,label = r'$ms_{D}=55$ GeV', c='red')
ax.plot(msD, msD60_125_cuts_releff, '--' ,label = r'$ms_{D}=60$ GeV', c='darkred')
'''
ax.plot(msD, msD5_125_cuts_releff, '--' ,label = r'$ms_{D}=5$ GeV', c=colors[0])
ax.plot(msD, msD15_125_cuts_releff, '--' ,label = r'$ms_{D}=15$ GeV', c=colors[1])
ax.plot(msD, msD20_125_cuts_releff, '--' ,label = r'$ms_{D}=20$ GeV', c=colors[2])
ax.plot(msD, msD25_125_cuts_releff, '--' ,label = r'$ms_{D}=25$ GeV', c=colors[3])
ax.plot(msD, msD30_125_cuts_releff, '--' ,label = r'$ms_{D}=30$ GeV', c=colors[4])
ax.plot(msD, msD35_125_cuts_releff, '--' ,label = r'$ms_{D}=35$ GeV', c=colors[5])
ax.plot(msD, msD40_125_cuts_releff, '--' ,label = r'$ms_{D}=40$ GeV', c=colors[6])
ax.plot(msD, msD45_125_cuts_releff, '--' ,label = r'$ms_{D}=45$ GeV', c=colors[7])
ax.plot(msD, msD50_125_cuts_releff, '--' ,label = r'$ms_{D}=50$ GeV', c=colors[8])
ax.plot(msD, msD55_125_cuts_releff, '--' ,label = r'$ms_{D}=55$ GeV', c=colors[9])
ax.plot(msD, msD60_125_cuts_releff, '--' ,label = r'$ms_{D}=60$ GeV', c=colors[10])
my_xticks = ['1GenMu24Eta2','2GenMu24Eta2','3GenMu8','4GenMu8', 'Decay in Phase 1 pixdet']
plt.xticks(msD, my_xticks)
ax.set_ylim([0,1])
plt.legend()
plt.grid()
plt.title(r'$MZ_{D}=125 \ GeV \ Rel. \ Eff.$') 
ax.set_facecolor('black')
fig.savefig('MZD_125_rel_eff.pdf')

# %%
##efficiencies for Zd=85 masses
msD5_85_cuts_totaleff=np.array([0.484, 0.215, 0.16, 0.0527, 0.0527])
msD5_85_cuts_releff=np.array([0.484, 0.444, 0.742, 0.33, 1])

msD15_85_cuts_totaleff=np.array([0.477, 0.192, 0.136, 0.0371, 0.0371])
msD15_85_cuts_releff=np.array([0.477, 0.403, 0.711, 0.272, 1])

msD20_85_cuts_totaleff=np.array([0.478, 0.188, 0.133, 0.038, 0.038])
msD20_85_cuts_releff=np.array([0.478, 0.394, 0.708, 0.285, 1])

msD25_85_cuts_totaleff=np.array([0.462, 0.176, 0.12, 0.0313, 0.0313])
msD25_85_cuts_releff=np.array([0.462, 0.382, 0.679, 0.262, 1])

msD30_85_cuts_totaleff=np.array([0.435, 0.149, 0.112, 0.0415, 0.0415])
msD30_85_cuts_releff=np.array([0.435, 0.341, 0.752, 0.372, 1])

msD35_85_cuts_totaleff=np.array([0.387, 0.106, 0.0969, 0.0557, 0.0557])
msD35_85_cuts_releff=np.array([0.387, 0.273, 0.917, 0.575, 1])

msD40_85_cuts_totaleff=np.array([0.3, 0.0612, 0.0594, 0.0448, 0.0448])
msD40_85_cuts_releff=np.array([0.3, 0.204, 0.971, 0.754, 1])

# %%
fig, ax = plt.subplots(figsize=(10,10))
colors=[]
for i in range (7):
    color = plt.cm.rainbow(np.linspace(1,0,7)[i])
    colors.append(color)
ax.plot(msD, msD5_85_cuts_totaleff, '--' ,label = r'$ms_{D}=5$ GeV', c=colors[0])
ax.plot(msD, msD15_85_cuts_totaleff, '--' ,label = r'$ms_{D}=15$ GeV', c=colors[1])
ax.plot(msD, msD20_85_cuts_totaleff, '--' ,label = r'$ms_{D}=20$ GeV', c=colors[2])
ax.plot(msD, msD25_85_cuts_totaleff, '--' ,label = r'$ms_{D}=25$ GeV', c=colors[3])
ax.plot(msD, msD30_85_cuts_totaleff, '--' ,label = r'$ms_{D}=30$ GeV', c=colors[4])
ax.plot(msD, msD35_85_cuts_totaleff, '--' ,label = r'$ms_{D}=35$ GeV', c=colors[5])
ax.plot(msD, msD40_85_cuts_totaleff, '--' ,label = r'$ms_{D}=40$ GeV', c=colors[6])

my_xticks = ['1GenMu24Eta2','2GenMu24Eta2','3GenMu8','4GenMu8', 'Decay in Phase 1 pixdet']
plt.xticks(msD, my_xticks)
plt.legend()
plt.grid()
ax.set_ylim([0,1])
plt.title(r'$MZ_{D}=85 \ GeV \ Total \ Eff.$') 
ax.set_facecolor('black')
fig.savefig('MZD_85_tot_eff.pdf')

# %%
fig, ax = plt.subplots(figsize=(10,10))
colors=[]
for i in range (7):
    color = plt.cm.rainbow(np.linspace(1,0,7)[i])
    colors.append(color)
ax.plot(msD, msD5_85_cuts_releff, '--' ,label = r'$ms_{D}=5$ GeV', c=colors[0])
ax.plot(msD, msD15_85_cuts_releff, '--' ,label = r'$ms_{D}=15$ GeV', c=colors[1])
ax.plot(msD, msD20_85_cuts_releff, '--' ,label = r'$ms_{D}=20$ GeV', c=colors[2])
ax.plot(msD, msD25_85_cuts_releff, '--' ,label = r'$ms_{D}=25$ GeV', c=colors[3])
ax.plot(msD, msD30_85_cuts_releff, '--' ,label = r'$ms_{D}=30$ GeV', c=colors[4])
ax.plot(msD, msD35_85_cuts_releff, '--' ,label = r'$ms_{D}=35$ GeV', c=colors[5])
ax.plot(msD, msD40_85_cuts_releff, '--' ,label = r'$ms_{D}=40$ GeV', c=colors[6])

my_xticks = ['1GenMu24Eta2','2GenMu24Eta2','3GenMu8','4GenMu8', 'Decay in Phase 1 pixdet']
plt.xticks(msD, my_xticks)
plt.legend()
plt.grid()
ax.set_ylim([0,1])
plt.title(r'$MZ_{D}=85 \ GeV \ rel. \ Eff.$') 
ax.set_facecolor('black')
fig.savefig('MZD_85_rel_eff.pdf')

# %% [markdown]
# #### $\epsilon^{2} \times scale factor$

# %% [markdown]
# we desire to replace $\sigma$ with $\epsilon^{2} \times scale factor$. Below are the list of $\epsilon$s that we tried:
# $\epsilon=10^{-5}, \epsilon=10^{-4}, \epsilon=10^{-3}, \epsilon=10^{-2}$

# %% [markdown]
# Masses are:
# $M_{Z_{D}}=85$ GeV, $M_{Z_{D}}=91$ GeV, $M_{Z_{D}}=95$ GeV, $M_{Z_{D}}=100$ GeV, $M_{Z_{D}}=110$ GeV, $M_{Z_{D}}=125$ GeV, $M_{Z_{D}}=130$ GeV, $M_{Z_{D}}=140$ GeV, $M_{Z_{D}}=150$ GeV, $M_{Z_{D}}=160$ GeV, $M_{Z_{D}}=170$ GeV, $M_{Z_{D}}=180$ GeV, $M_{Z_{D}}=190$ GeV, $M_{Z_{D}}=200$ GeV

# %% [markdown]
# Scale factors are: $a=1.45\mathrm{e}{+07}, 2.40\mathrm{e}{+08}, 6.93\mathrm{e}{+07}, 2.57\mathrm{e}+07, 1.23\mathrm{e}{+07}, 1.03\mathrm{e}{+07}, 7.46\mathrm{e}{+06}, 5.72\mathrm{e}{+06}, 4.49\mathrm{e}{+06}, 3.61\mathrm{e}{+06}, 2.92\mathrm{e}{+06}, 2.42\mathrm{e}{+06}, 2.02\mathrm{e}{+06}$
